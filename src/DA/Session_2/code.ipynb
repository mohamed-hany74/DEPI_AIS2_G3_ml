# %%
import pandas as pd

# %%
import pandas as pd


df = pd.DataFrame({
    "Name": ["Ahmed", "Sara", "Mona"],
    "Age": [25, 30, 22]
})

pd.value_counts(df)
# Out:
# C:\Users\almnara\AppData\Local\Temp\ipykernel_13460\366851832.py:9: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df)
# C:\Users\almnara\AppData\Local\Temp\ipykernel_13460\366851832.py:9: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.value_counts(df)
# Name    1
# Age     1
# Name: count, dtype: int64

# %%
pd.value_counts(df)
# Out:
# C:\Users\almnara\AppData\Local\Temp\ipykernel_13460\4010155336.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df)
# C:\Users\almnara\AppData\Local\Temp\ipykernel_13460\4010155336.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.value_counts(df)
# Name    1
# Age     1
# Name: count, dtype: int64

# %%
s1 = [1,0,2,1,3,1]
s1 =pd.Series(s1,index= [0,1,2,3,4,5])
s1.loc[0] = 55
s1[s1 >= 0 ] = 5 
print(s1)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
df =pd.read_csv('test.csv')

df = df.drop(['Benefits','Year' , 'TotalPayBenefits'],axis=1)
print(df.head())
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay   TotalPay
# 0  167411.18         0.00  400184.25  567595.43
# 1  155966.02    245131.88  137811.38  538909.28
# 2  212739.13    106088.18   16452.60  335279.91
# 3   77916.00     56120.71  198306.90  332343.61
# 4  134401.60      9737.00  182234.59  326373.19

# %%
df.TotalPay.mode()
# Out:
# 0     251685.16
# 1     251935.01
# 2     253269.44
# 3     257124.44
# 4     257540.09
# 5     258364.22
# 6     258588.39
# 7     259684.88
# 8     259927.11
# 9     260297.66
# 10    261366.14
# 11    264074.60
# 12    265463.46
# 13    265784.56
# 14    267992.59
# 15    270324.91
# 16    270672.63
# 17    273702.71
# 18    273771.21
# 19    274190.27
# 20    274550.25
# 21    276434.22
# 22    278569.21
# 23    284720.43
# 24    286213.86
# 25    286347.05
# 26    292671.62
# 27    294580.02
# 28    297608.92
# 29    299494.17
# 30    302377.73
# 31    303427.55
# 32    307899.46
# 33    315981.05
# 34    316285.74
# 35    326373.19
# 36    332343.61
# 37    335279.91
# 38    538909.28
# 39    567595.43
# Name: TotalPay, dtype: float64

# %%
s =pd.Series([1,2,3,4,5] , index= ['A','B','C','D','H'])
s
# Out:
# A    1
# B    2
# C    3
# D    4
# H    5
# dtype: int64

# %%
data = [[1,255,'a',4],
        [2,454,'b',45],
        [3,565,'w','a'],
        [4,554]]

df = pd.DataFrame(data , columns=['colum 1','colum 2','colum','colum'] )
c = ['colum 1','colum 2','colum 3 ','colum 4']
df.columns=c
ind = ['Row 1', 'Row 2' , 'Row 3  ' ,'Row 4'] 
df.index =ind
df
# Out:
#          colum 1  colum 2 colum 3  colum 4
# Row 1          1      255        a       4
# Row 2          2      454        b      45
# Row 3          3      565        w       a
# Row 4          4      554     None    None

# %%
data = {'column 1':[1,2,3,4],
        'column 2':[123,454,46,45],
        'column 3':['f','s','d',5]}

df = pd.DataFrame(data)
df
# Out:
#    column 1  column 2 column 3
# 0         1       123        f
# 1         2       454        s
# 2         3        46        d
# 3         4        45        5

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
np.arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 np.arr
#
# NameError: name 'np' is not defined

# %%
data = [1001,200,24521,552,4,54,6]
series = pd.Series(data,index=['a','b','c','f','g','h','j'])
series.loc[0]= 52
print(series[series <= 200])
# Out:
# b    200
# g      4
# h     54
# j      6
# 0     52
# dtype: int64

# %%
df = pd.read_csv("test.csv")
df.head()
df = df.drop('Year', axis=1)
df = df.drop('Benefits' , axis= 1)

df.head(4)
df['TotalPay'] = df['TotalPay'].astype('int64')
df['OtherPay'] = df['OtherPay'].astype('int64')
df.head(4)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
#
#      BasePay  OvertimePay  OtherPay  TotalPay  TotalPayBenefits
# 0  167411.18         0.00    400184    567595         567595.43
# 1  155966.02    245131.88    137811    538909         538909.28
# 2  212739.13    106088.18     16452    335279         335279.91
# 3   77916.00     56120.71    198306    332343         332343.61

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'TotalPay', 'TotalPayBenefits'],
#       dtype='object')

# %%
df['BasePay'].unique()
# Out:
# array([167411.18, 155966.02, 212739.13,  77916.  , 134401.6 , 118602.  ,
#         92492.01, 256576.96, 176932.64, 285262.  , 194999.39,  99722.  ,
#        294580.02, 271329.03, 174872.64, 198778.01, 268604.57, 140546.87,
#        168692.63, 257510.59, 257510.48, 257510.44, 140546.88, 140546.86,
#        256470.41,  92080.8 , 168692.59, 261717.6 , 246225.6 , 234325.02,
#        254027.63, 248895.7 , 104861.39, 177781.25, 101953.2 , 245124.44,
#        110661.2 , 132202.26, 147158.85])

# %%
df['TotalPay'].min()
# Out:
# np.int64(251685)

# %%
df['TotalPay'].idxmin()
# Out:
# 39

# %%
report = data_analysis_report(df)

report['numeric_describe']
report['missing_percentage']
report['suggested_drop_columns']
# Out:
# []

# %%
def get_feature(df ) :

# %%
get_feature(df)
# Out:
# (Id                      40.00
#  BasePay             294580.02
#  OvertimePay         245131.88
#  OtherPay            400184.25
#  TotalPay            567595.43
#  TotalPayBenefits    567595.43
#  dtype: float64,
#  Id                       1.00
#  BasePay              77916.00
#  OvertimePay              0.00
#  OtherPay                 0.00
#  TotalPay            251685.16
#  TotalPayBenefits    251685.16
#  dtype: float64,
#  Id                      20.50000
#  BasePay             187373.01300
#  OvertimePay          47126.84525
#  OtherPay             59835.69625
#  TotalPay            294335.55450
#  TotalPayBenefits    294335.55450
#  dtype: float64,
#      Id    BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits
#  0    1  168692.63          0.0       0.00  251685.16         251685.16
#  1    2        NaN          NaN    2357.00  251935.01         251935.01
#  2    3        NaN          NaN    5899.48  253269.44         253269.44
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# dtype: int64

# %%
df.iloc[: 2]
df['TotalPayBenefits'] = df.TotalPay - df.TotalPayBenefits

df.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay  OtherPay  TotalPay  TotalPayBenefits
# 0  167411.18         0.00    400184    567595         567595.43
# 1  155966.02    245131.88    137811    538909         538909.28
# 2  212739.13    106088.18     16452    335279         335279.91
# 3   77916.00     56120.71    198306    332343         332343.61
# 4  134401.60      9737.00    182234    326373         326373.19

# %%
df.to_csv('new.csv')

# %%
dfn = pd.read_csv('new.csv')
dfn.head(5)
# Out:
#    Unnamed: 0  Id       EmployeeName  \
# 0           0   1     NATHANIEL FORD
# 1           1   2       GARY JIMENEZ
# 2           2   3     ALBERT PARDINI
# 3           3   4  CHRISTOPHER CHONG
# 4           4   5    PATRICK GARDNER
#
#                                          JobTitle    BasePay  OvertimePay  \
# 0  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                 CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                 CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3            WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
#
#    OtherPay  TotalPay  TotalPayBenefits
# 0    400184    567595         567595.43
# 1    137811    538909         538909.28
# 2     16452    335279         335279.91
# 3    198306    332343         332343.61
# 4    182234    326373         326373.19

# %%
df.shape
# Out:
# (40, 8)

# %%
df['JobTitle'].head(5)
# Out:
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                   CAPTAIN III (POLICE DEPARTMENT)
# 2                   CAPTAIN III (POLICE DEPARTMENT)
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
mean = df.TotalPay.mean()
df.JobTitle = df.JobTitle.fillna(value= mean)

# %%
nul = df.isnull().sum()
pd.DataFrame(nul).T
# Out:
#    Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  TotalPay  \
# 0   0             0         0        0            0         0         0
#
#    TotalPayBenefits
# 0                 0

# %%
new = {'EmployeeName': ' mohaned '}

# %%
new = df.Id
df.insert(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[370], line 2
#       1 new = df.Id
# ----> 2 df.insert(0)
#
# TypeError: DataFrame.insert() missing 2 required positional arguments: 'column' and 'value'

# %%
def get_feature(df , column ):
    
    duplicated = df.duplicated().sum()
    nulls = df.isnull().sum().sum()
    max_v = df[column].max()
    min_v = df[column].min()
    
    return f"your nulls {nulls}  duplicated rows {duplicated} max in your colum {max_v}"

# %%
get_feature(df,column='TotalPay')
# Out:
# 'your nulls 0  duplicated rows 0 max in your colum 567595'

# %%
def get_feature(df):
    duplicates = df.duplicated().sum()
    nulls = df.isnull().sum().sum()
    return {"duplicates": duplicates, "nulls": nulls}

# %%
get_feature(df)
# Out:
# {'duplicates': np.int64(0), 'nulls': np.int64(0)}

# %%
max_v, min_v, mean_v,mode_vals = get_feature(df)
print("-------------mix-----------")

print(max_v)
print("-------------min-----------")

print(min_v)

print("-------------mean-----------")

print(mean_v)
# Out:
# -------------mix-----------
# Id                      40.00
# BasePay             294580.02
# OvertimePay         245131.88
# OtherPay            400184.25
# TotalPay            567595.43
# TotalPayBenefits    567595.43
# dtype: float64
# -------------min-----------
# Id                       1.00
# BasePay              77916.00
# OvertimePay              0.00
# OtherPay                 0.00
# TotalPay            251685.16
# TotalPayBenefits    251685.16
# dtype: float64
# -------------mean-----------
# Id                      20.50000
# BasePay             187373.01300
# OvertimePay          47126.84525
# OtherPay             59835.69625
# TotalPay            294335.55450
# TotalPayBenefits    294335.55450
# dtype: float64
#     Id    BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits
# 0    1  168692.63          0.0       0.00  251685.16         251685.16
# 1    2        NaN          NaN    2357.00  251935.01         251935.01
# ...

# %%
df.describe()
# Out:
#        column 1    column 2
# count  4.000000    4.000000
# mean   2.500000  167.000000
# std    1.290994  194.790486
# min    1.000000   45.000000
# 25%    1.750000   45.750000
# 50%    2.500000   84.500000
# 75%    3.250000  205.750000
# max    4.000000  454.000000

# %%
df['TotalPay'] = df['TotalPay'].astype('int64')
df['OtherPay'] = df['OtherPay'].astype('int64')

# %%
#df.replace('NATHANIEL FORD','mohamed hany')

# %%
df.idx
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33860\2300584396.py in ?()
# ----> 1 df.idx
#
# e:\AMIT\DEPI_AIS2_G3_ml\env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'idx'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                40 non-null     int64
#  1   EmployeeName      40 non-null     object
#  2   JobTitle          40 non-null     object
#  3   BasePay           40 non-null     float64
#  4   OvertimePay       40 non-null     float64
#  5   OtherPay          40 non-null     int64
#  6   TotalPay          40 non-null     int64
#  7   TotalPayBenefits  40 non-null     float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 2.6+ KB

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# TotalPay              int64
# TotalPayBenefits    float64
# dtype: object

# %%
S= pd.Series([8,2,3,4,5])
ind = ([0,1,2,3,4])
S.index = ind
S.loc[0] = 58
print(S[S >= 5])
# Out:
# 0    58
# 4     5
# dtype: int64

# %%
mat = ({'column 1'  : [1,2,3,4,5],
        'coulumn 2' : [4,5,6,7,8],
        'coulumn 3' : [1,2,52,3,5]})


ind = ['a','b','c','f','g']



mat = pd.DataFrame(mat)
mat.index = ind


print(display(mat))
# Out:
#    column 1  coulumn 2  coulumn 3
# a         1          4          1
# b         2          5          2
# c         3          6         52
# f         4          7          3
# g         5          8          5
# None

# %%
cols = ['column 1','coulumn 2']
mat[cols] = mat[cols].astype('int')

# %%
mat['column 1'].dtypes
# Out:
# dtype('int64')

# %%
c = {'day1': 1544,'day2':225} 
c = pd.Series(c)
c.loc['day1'] += 500 

print(c[c > 1000])
# Out:
# day1    2044
# dtype: int64

# %%
c = {'day 1 ': [1544],'day2':[225]} 
c = pd.DataFrame(c)
ind = [1]
c.index = ind
c
# Out:
#    day 1   day2
# 1    1544   225

# %%
mat2 = [[1,2,3,4,5],
        [2,3,4,5,4],
        [3,4,5,4,5]]
mat2 = pd.DataFrame(mat2)
ind = ['a','b','c']

mat2.index = ind


mat2
# Out:
#    0  1  2  3  4
# a  1  2  3  4  5
# b  2  3  4  5  4
# c  3  4  5  4  5
