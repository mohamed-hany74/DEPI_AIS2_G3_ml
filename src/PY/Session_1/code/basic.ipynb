# %%
x = 45
a = 56
s = a+x

print(s)
# Out:
# 101

# %%
x = 4
print ('wallcom into debi',x)
# Out:
# wallcom into debi 4

# %%
x = 55
print( type(x))
# Out:
# <class 'int'>

# %%
name = 'mohamed hany'
age = 56
print(name,age)
# Out:
# mohamed hany 56

# %%
name="mohamed hany"
course_name="ml"
course_id="mlG3"
print(f"my name is {name} and my cours is {course_id} and my id is {course_id}  ")
# Out:
# my name is mohamed hany and my cours is mlG3 and my id is mlG3

# %%
name = "mohamed hany  hany "
print(name.capitalize())
print(name.title())


name_upper=print(name.upper())
name_lower=print(name.lower())
name_replace=print(name.replace("hany","hamed"))
# Out:
# Mohamed hany  hany
# Mohamed Hany  Hany
# MOHAMED HANY  HANY
# mohamed hany  hany
# mohamed hamed  hamed

# %%
name = "mohamed hany   khalf kandeel "
name_split=name.split()
print(name.count("a"))
print(name.split())
sant= ' ' .join((name_split))
# Out:
# 4
# ['mohamed', 'hany', 'khalf', 'kandeel']
