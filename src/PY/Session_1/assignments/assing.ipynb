# %%
massage = "###!!@mocleW EPGTQ!!!6789"
new_massage =  massage[6:]
massage_new=new_massage[0:13:]
massage_new2=massage_new [0::].split()
massage_new11= massage_new2[0] [::-1]

#print(massage_new11)
massage = "###!!@mocleW EPGTQ!!!6789"
new_massage2 = massage[13:]
new_massage2222=massage[13:14].lower()
#print(new_massage2222)

massage_new2 = new_massage2[:-7]
massage_new222 = massage_new2[1:]
#massage_new222=''.join(massage_new11)
massage_new2=''.join(new_massage2222)
print(massage_new11+new_massage2222 + " "+ massage_new222 )
# Out:
# Welcome PGTQ

# %%
massage = "###!!@mocleW EPGTQ!!!6789"
massage5=list(massage[0:])
del massage5 [ 0:6]
 
del massage5 [17:]

print(massage5)
setet="".join(massage5)
setet2=setet[::-1]
print(setet2)
# Out:
# ['m', 'o', 'c', 'l', 'e', 'W', ' ', 'E', 'P', 'G', 'T', 'Q', '!', '!', '!', '6', '7']
# 76!!!QTGPE Welcom

# %%
Name ="mohamed hany "
agr  = "23"
print(f"my name { Name.title() } AND my age {agr.title()}") 
a = 10
b = 3
c = 2
print( int((a + b) * c))
s = "amit learning"
print(s[-3])
# Out:
# my name Mohamed Hany  AND my age 23
# 26
# i

# %%
emil = "Amit_ml@gmail.edu"
if "@" in emil and "." in emil :

    print("v")
else  :
   print("n v")    

emil1=emil.split("@")
del emil1 [-1]

print(emil1)
emil2=emil.split("@")
del emil2 [0:1]

print(emil2)
if emil.endswith('.com') :
    print("comm domin")
elif emil.endswith(".edu") :
    print("edu domin")    
else :
    print("other")
# Out:
# v
# ['Amit_ml']
# ['gmail.edu']
# edu domin
