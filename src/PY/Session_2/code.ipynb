# %%
list_1 = [1 , 2, 3, "depi" , "leanring" , True , ['ds','ml' 'mm']]
list_1
# Out:
# [1, 2, 3, 'depi', 'leanring', True, ['ds', 'mlmm']]

# %%
list_1.insert(0,"mohamed")
print(list_1)
# Out:
# ['mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 'mohamed', 1, 2, 3, 'depi', 'leanring', True, ['ds', 'mlmm']]

# %%
list_1 = [1 , 23 , 25]
list_2 = [1 , 12 , 24 ]
print(list_1 + list_2)
# Out:
# [1, 23, 25, 1, 12, 24]

# %%
list_1.extend(list_2)
print(list_1)
# Out:
# [1, 23, 25, 1, 12, 24, 1, 12, 24]

# %%
list_1 = [1 , 5  , 1 ,  23 , 25] 
list_1.remove(1)
print(list_1)
# Out:
# [5, 1, 23, 25]

# %%
list_1 = [1 ,  0 , 23 , 25] 
list_1
print(list_1)
del list_1[0 : 2]
print(list_1)
# Out:
# [1, 0, 23, 25]
# [23, 25]

# %%
name  = input("enter your name ")
ib = input("enter your id")
print ( f"your name {name} and your age {id}")
# Out:
# your name n and your age <built-in function id>

# %%
name = input("enter your name ")
ib = input("enter your id ")

print(f"your name {name} and your id {ib}")
# Out:
# your name nvcvm and your id vvvv

# %%
list_22 = ["amit" , "learning" , "py" , "ml"]
list_del = input("enter your num")
list_22.remove(list_del)
print(list_22)
# Out:
# ['amit', 'learning', 'ml']

# %%
list_3 = [1 , 1  ,3 , 4]
#print(list_3.index(4))
#print(list_3.count(1))
list_3 = [1, 1, 3, 4]
list_3.sort()
print(list_3)

list_3 =  list_3.sort()
print(list_3)
# Out:
# [1, 1, 3, 4]
# None

# %%
tuple_1 = (1 ,21 , 2)
tuple_1[0]
list = tuple_1
print(tuple_1)
# Out:
# (1, 21, 2)

# %%
set_1= {1,2,22,5,55}
set_2={5,55,22,21,1}
set.difference

# %%
dict_1= {"key":1,"key2":"mo"}
dict_1["key"]=50


print(dict_1)
# Out:
# {'key': 50, 'key2': 'mo'}

# %%
num= int(input("enter num"))
num2=int(input("enter num"))
sum=num+num2
sub= num-num2
mlt=num*num2
div=num/num2



print(sum )
print(sub )
print(mlt )
print(div )
print(sum )
# Out:
# 4
# 0
# 4
# 1.0
# 4

# %%
x=20
y=5

r=(x+True) / (4-y*False)
print(r)
# Out:
# 5.25

# %%
a=200
s=200
if a < s:
    print("a")
elif a==s : 
     print("dd")
         
else:

     print("s")
# Out:
# dd

# %%
x = 5
y = -15
if x > 0 and y > 0 :
    print("+")
else :
    print("-")
# Out:
# -

# %%
x = 5 
r ="even " if x % 2 == 0 else "ood"
print(r)
# Out:
# ood

# %%
s=12
c=564
r=s+c if s>c else s-c 
print(r)
# Out:
# -552

# %%
age = 10
agee= "kbear" if age >= 10 else "ddd"

# %%
degree=int(input("enter your"))

if 0 < degree <= 100:
   if 90 <degree<= 100:
    print("A")

   elif 70 <degree<= 90:
    print("b")

   elif 60 <degree<= 70:
    print("c")
   elif  degree< 60:
    print("f")
else :
    print("non")
# Out:
# non

# %%
for i in range(5):
    print("mm")
else :
    print("as")
# Out:
# mm
# mm
# mm
# mm
# mm
# as

# %%
for i in range(6):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(6):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
num1 = int(input("enter your num"))
num2 = int(input("enter your num"))
opp = input("enter your opration sum  mlt div all")

if opp == "sum" :
    sum = num1 +  num2 
    print(sum)
elif  opp == "mlt" :
    mlt= num1 *  num2 
    print(mlt)
elif  opp == "div" :
    div= num1 /  num2 
    print(div)   
elif  opp == "all" :
    mlt= num1 *  num2 
    div= num1 /  num2 
    sum = num1 +  num2 


    print(f"sum  = { sum } mlt = { mlt } div = { div }")
# Out:
# sum  = 10 mlt = 25 div = 1.0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
