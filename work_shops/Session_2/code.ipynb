# %%
name = ' mohamed hany '

# %%
list1 = [1,2,3,4,5]
list1[1] = 252

# %%
list1.append(2)

# %%
list1
# Out:
# [1, 252, 3, 4, 5, 2]

# %%
name = 'mohamed'
age = 25 
gread = 72

# %%
print(f'my name is {name} and my age is {age} and my gread {gread}')
# Out:
# my name is mohamed and my age is 25 and my gread 72

# %%
last = 'hany'

# %%
def sum(num1 , num2) :
    return num1 + num2

# %%
sum(45,45)
# Out:
# 90

# %%
total = name+" " +last
total
# Out:
# 'mohamed hany'

# %%
age = 52
intrast = 'ml'

# %%
if age <= 20 or intrast == 'ml' :
    print('yes')
else : 
    print('no')
# Out:
# yes

# %%
try :
  gread = float(input('enter your number'))

  if gread > 100 or gread < 0 :

     print('wrong')

  elif  gread >= 85 and gread <= 100 :

      print('A')

  elif gread < 85 and gread >= 75 : 

     print('B')

  elif gread < 75 and gread >= 60 :

      print('C')   

  elif gread < 60 and gread >= 50 :

      print('D')

  elif gread < 50 :

      print('fill')    

except  ValueError as a :
   print(a)
# Out:
# D
