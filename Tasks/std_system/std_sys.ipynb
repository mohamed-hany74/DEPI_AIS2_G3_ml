# %%
class Student:
    _id_counter = 1
    
    def __init__(self, name):
        if not name:
            raise ValueError("Name cannot be empty")
        self.student_id = Student._id_counter
        Student._id_counter += 1
        self.name = name
        self.grades = {}
        self.enrolled_courses = []
    
    def __str__(self):
        return f"Student ID : {self.student_id}, Name : {self.name}, Grades:  {(self.grades)}"
    
    def __repr__(self):
        return f"Student ID : {self.student_id}, Name : {self.name}, Grades:  {(self.grades)}"
    
    def add_grade(self, course_id ,grade):
        if not 0 <= grade <= 100:
            raise ValueError("grades must be between 0 and 100")
        self.grades[course_id] = grade
    
    def enroll_in_course(self, course):
        if course in self.enrolled_courses:
            print(f"{self.name} is already enrolled in {course}")
        else:
            self.enrolled_courses.append(course)

# %%
s1 = Student("george")
s1.add_grade(1,110)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 s1 = Student("george")
# ----> 2 s1.add_grade(1,110)
#
# Cell In[33], line 21, in Student.add_grade(self, course_id, grade)
#      19 def add_grade(self, course_id ,grade):
#      20     if not 0 <= grade <= 100:
# ---> 21         raise ValueError("grades must be between 0 and 100")
#      22     self.grades[course_id] = grade
#
# ValueError: grades must be between 0 and 100

# %%
s1
# Out:
# Student ID : 1, Name : Mohammed, Grades:  {1: 90}

# %%
name = input("Enter Your Name")
def add_student(name):
    s1 = Student(name)
    return s1.student_id

# %%
name = input("Enter Your Name")

add_student(name)
# Out:
# 'Student ID : 3, Name : george, Grades:  {}'

# %%
import unittest
class TestStudent(unittest.TestCase):
    
    def setUp(self):
        self.student = Student("George")
        
    def test_add_grade(self):
        self.student.add_grade("ML",90)

unittest.main(argv=['first-arg-is-ignore'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %%
from student import Student
class Course:
    _id_counter = 1
    
    def __init__(self, name):
        self.course_id = Course._id_counter
        Course._id_counter += 1
        self.name = name
        self.enrolled_students = []
    def __str__(self):
        return f"course ID : {self.course_id}, Name : {self.name}, Enrolled: {len(self.enrolled_students)}"
    def __repr__(self):
        return f"course ID : {self.course_id}, Name : {self.name}, Enrolled: {len(self.enrolled_students)}"

    def enroll_student(self, student):
        if student not in self.enrolled_students:
            self.enrolled_students.append(student)
            print(f"student enrolled successfully in {self.name}")
        else:
            print(f"student is already enrolled in {self.name}")
    
    def remove_student(self, student):
        if student in self.enrolled_students:
            self.enrolled_students.remove(student)
            print(f"student removed from {self.name}")
        else:
            print(f"student is not enrolled in {self.name}")

# %%
c1 = Course("ml")
c1.enroll_student("george")
# Out:
# student enrolled successfully in ml

# %%
c2 = Course("ml")
c2.enroll_student("ahmed")
# Out:
# student enrolled successfully in ml

# %%
str(c2)
# Out:
# 'course ID : 2, Name : ml, Enrolled: 1'

# %%
import unittest
class TestCourse(unittest.TestCase):
    
    def setUp(self):
        self.course = Course("ML")
        
    def test_enrolled_std(self):
        self.course.enroll_student("george")

unittest.main(argv=['first-arg-is-ignore'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.006s
#
# OK
# student enrolled successfully in ML

# %%
from student import Student
class SystemManager:
    
    def __init__(self):
        self.students = {}
        self.courses = {}
        
    def add_student(self, name):
        student =  Student(name)
        self.students[student.student_id] = student
        print(f"student added successfully!.")
        return student.student_id
    def remove_student(self, student_id):
        if student_id in self.students:
            student = self.students[student_id]
            for course in list(student.enrolled_courses):
                course.remove(student)
            del self.students[student_id]
            print("student removed successfully.")
        else:
            print("Invalid student id")
